# %% [markdown]
# # Experiment-2
# Write a simple Python program to display messages on screen

# %%
print("Welcome to the Python Programming Lab.")
# Out:
# Welcome to the Python Programming Lab.

# %%
print("This is a simple program to\ndemonstrate printing messages in Python.")
# Out:
# This is a simple program to
# demonstrate printing messages in Python.

# %%
print("Hello, World",end="!")
# Out:
# Hello, World!

# %%
name = "Bhavneet Bhagat"
age = 24

print(name)
print(age)
# Out:
# Bhavneet Bhagat
# 24

# %%
sub = "Python programming lab"
exp = 2

print(f"This is experiment no. {exp} of {sub}")
# Out:
# This is experiment no. 2 of Python programming lab

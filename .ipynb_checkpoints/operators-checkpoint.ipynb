# %% [markdown]
# # Experiment-3
# Write program using operators.

# %% [markdown]
# # 1). Arithmetic operators

# %%
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))

print(f"a = {a}, b = {b}")
print(f"Addition (a + b) = {a + b}")
print(f"Subtraction (a - b) = {a - b}")
print(f"Multiplication (a * b) = {a * b}")
print(f"Division (a / b) = {a / b}")
print(f"Floor Division (a // b) = {a // b}")
print(f"Modulus (a % b) = {a % b}")
print(f"Exponentiation (a ** b) = {a ** b}")
# Out:
# Enter the value of a: 20
# Enter the value of b: 2
# a = 20, b = 2
# Addition (a + b) = 22
# Subtraction (a - b) = 18
# Multiplication (a * b) = 40
# Division (a / b) = 10.0
# Floor Division (a // b) = 10
# Modulus (a % b) = 0
# Exponentiation (a ** b) = 400

# %% [markdown]
# # 2). Relational operators

# %%
x = int(input("Enter the value of x: "))
y = int(input("Enter the value of y: "))

print(f"x = {x}, y = {y}")
print(f"x == y: {x == y}")
print(f"x != y: {x != y}")
print(f"x > y: {x > y}")
print(f"x < y: {x < y}")
print(f"x >= y: {x >= y}")
print(f"x <= y: {x <= y}")
# Out:
# Enter the value of x: 15
# Enter the value of y: 5
# x = 15, y = 5
# x == y: False
# x != y: True
# x > y: True
# x < y: False
# x >= y: True
# x <= y: False

# %% [markdown]
# # 3). Logical operators

# %%
p = True
q = False

print(f"p = {p}, q = {q}")
print(f"p and q: {p and q}")
print(f"p or q: {p or q}")
print(f"not p: {not p}")
# Out:
# p = True, q = False
# p and q: False
# p or q: True
# not p: False

# %% [markdown]
# # 4). Bitwise operators

# %%
m = 12 
n = 10 

print(f"m = {m} (Binary: {bin(m)}), n = {n} (Binary: {bin(n)})")
print(f"m & n (AND): {m & n} (Binary: {bin(m & n)})")
print(f"m | n (OR): {m | n} (Binary: {bin(m | n)})")
print(f"m ^ n (XOR): {m ^ n} (Binary: {bin(m ^ n)})")
print(f"~m (NOT): {~m}")
print(f"m << 2 (Left Shift): {m << 2}")
print(f"m >> 2 (Right Shift): {m >> 2}")
# Out:
# m = 12 (Binary: 0b1100), n = 10 (Binary: 0b1010)
# m & n (AND): 8 (Binary: 0b1000)
# m | n (OR): 14 (Binary: 0b1110)
# m ^ n (XOR): 6 (Binary: 0b110)
# ~m (NOT): -13
# m << 2 (Left Shift): 48
# m >> 2 (Right Shift): 3

# %% [markdown]
# # 5). Assignment operators

# %%
num = 50

print(f"num = {num}")
num += 10 
print(f"After += 10: num = {num}")

num -= 5  
print(f"After -= 5: num = {num}")

num *= 2  
print(f"After *= 2: num = {num}")

num /= 4 
print(f"After /= 4: num = {num}")

num //= 3 
print(f"After //= 3: num = {num}")
# Out:
# num = 50
# After += 10: num = 60
# After -= 5: num = 55
# After *= 2: num = 110
# After /= 4: num = 27.5
# After //= 3: num = 9.0

# %% [markdown]
# # 6). Identity operators

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list3 = list1

print(f"list1 = {list1}")
print(f"list2 = {list2}")
print(f"list3 = list1")
print(f"list1 is list2: {list1 is list2}")
print(f"list1 is list3: {list1 is list3}")
print(f"list1 is not list2: {list1 is not list2}")
# Out:
# list1 = [1, 2, 3]
# list2 = [4, 5, 6]
# list3 = list1
# list1 is list2: False
# list1 is list3: True
# list1 is not list2: True

# %% [markdown]
# # 7). Membership operators

# %%
arr = [10,20,30,40,50]
print(f"array = {arr}")
print(f"'10' in array: {10 in arr}")
print(f"'30' in array: {30 in arr}")
print(f"'60' not in array: {60 not in arr}")
# Out:
# array = [10, 20, 30, 40, 50]
# '10' in array: True
# '30' in array: True
# '60' not in array: True
